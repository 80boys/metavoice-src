# %% [markdown]
# ## Installation

# %% [markdown]
# ### Clone the repository

# %%
# !git clone https://github.com/metavoiceio/metavoice-src.git
# %cd metavoice-src
# Out:
# Cloning into 'metavoice-src'...
# remote: Enumerating objects: 589, done.
# remote: Counting objects: 100% (303/303), done.
# remote: Compressing objects: 100% (172/172), done.
# remote: Total 589 (delta 207), reused 177 (delta 122), pack-reused 286 (from 1)
# Receiving objects: 100% (589/589), 20.25 MiB | 26.55 MiB/s, done.
# Resolving deltas: 100% (327/327), done.
# /content/metavoice-src

# %% [markdown]
# ### Install dependencies

# %%
# !sudo apt install pipx
# !pipx install poetry
# !pipx run poetry install && pipx run poetry run pip install torch==2.2.1 torchaudio==2.2.1
# !pipx run poetry env list | sed 's/ (Activated)//' > poetry_env.txt
# NOTE: pip's dependency resolver will error & complain, ignore it!
# its due to a temporary dependency issue, `tts.synthesise` will still work as intended!
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 60%
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8): Installing...
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2): Pending...
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2): Pending...
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2): Pending...
#   - Installing tzdata (2024.1): Pending...
#   - Installing tzdata (2024.1): Pending...
#   - Installing tqdm (4.66.2): Downloading... 0%
#   - Installing tzdata (2024.1): Pending...
#   - Installing tzdata (2024.1): Pending...
#   - Installing tqdm (4.66.2): Downloading... 100%
#   - Installing tzdata (2024.1): Pending...
#   - Installing tzdata (2024.1): Pending...
#   - Installing tqdm (4.66.2): Installing...
#   - Installing tzdata (2024.1): Pending...
#   - Installing tzdata (2024.1): Downloading... 0%
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2): Installing...
#   - Installing tzdata (2024.1): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 70%
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2): Installing...
#   - Installing tzdata (2024.1): Downloading... 0%
#   - Installing tzdata (2024.1): Downloading... 100%
#   - Installing tzdata (2024.1): Installing...
#   - Installing tzdata (2024.1): Installing...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing numpy (1.26.4): Downloading... 80%
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing numpy (1.26.4): Downloading... 90%
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 0%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing torch (2.1.0): Downloading... 1%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 1%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing numpy (1.26.4): Downloading... 100%
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 1%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1): Installing...
#   - Installing tzdata (2024.1)
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 1%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing numpy (1.26.4): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 1%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 5%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing anyio (4.3.0)
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.5)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0)
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 5%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing antlr4-python3-runtime (4.9.3): Installing...
#   - Installing anyio (4.3.0)
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.5)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0)
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 5%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing anyio (4.3.0)
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.5)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0)
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 5%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing antlr4-python3-runtime (4.9.3)
#   - Installing anyio (4.3.0)
#   - Installing click (8.1.7)
#   - Installing cloudpickle (3.0.0)
#   - Installing cymem (2.0.8)
#   - Installing httpcore (1.0.5)
#   - Installing jsonschema-specifications (2023.12.1)
#   - Installing markdown-it-py (3.0.0)
#   - Installing murmurhash (1.0.10)
#   - Installing numpy (1.26.4): Installing...
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 5%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 10%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 16%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 16%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing numpy (1.26.4)
#   - Installing packaging (23.2)
#   - Installing pycparser (2.22)
#   - Installing pydantic (2.7.0)
#   - Installing pygments (2.17.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.31.0)
#   - Installing srsly (2.4.8)
#   - Installing torch (2.1.0): Downloading... 16%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 20%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 29%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 40%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 47%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 48%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 50%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 60%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 68%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 80%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 90%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Downloading... 100%
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0): Installing...
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing torch (2.1.0)
#   - Installing tqdm (4.66.2)
#   - Installing tzdata (2024.1)
#   - Installing asttokens (2.4.1): Pending...
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing asttokens (2.4.1): Downloading... 0%
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing colorama (0.4.6): Downloading... 0%
#   - Installing confection (0.1.4): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing colorama (0.4.6): Downloading... 100%
#   - Installing confection (0.1.4): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing asttokens (2.4.1): Downloading... 100%
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing asttokens (2.4.1): Installing...
#   - Installing blis (0.7.11): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing blis (0.7.11): Downloading... 0%
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing blis (0.7.11): Downloading... 0%
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing asttokens (2.4.1)
#   - Installing blis (0.7.11): Downloading... 0%
#   - Installing cffi (1.16.0): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6): Installing...
#   - Installing confection (0.1.4): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing confection (0.1.4): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cffi (1.16.0): Downloading... 0%
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cffi (1.16.0): Downloading... 100%
#   - Installing cloudpathlib (0.16.0): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cloudpathlib (0.16.0): Downloading... 0%
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cloudpathlib (0.16.0): Downloading... 100%
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Downloading... 0%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing confection (0.1.4): Downloading... 100%
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Pending...
#   - Installing cycler (0.12.1): Downloading... 0%
#   - Installing cycler (0.12.1): Downloading... 100%
#   - Installing cycler (0.12.1): Installing...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Installing...
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Installing...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Installing...
#   - Installing cffi (1.16.0): Installing...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4): Installing...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1): Installing...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Pending...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing contourpy (1.2.1): Downloading... 0%
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing cffi (1.16.0): Installing...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Downloading... 0%
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing blis (0.7.11): Downloading... 20%
#   - Installing cffi (1.16.0): Installing...
#   - Installing cloudpathlib (0.16.0): Installing...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Downloading... 0%
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Downloading... 0%
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Downloading... 0%
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing contourpy (1.2.1): Downloading... 100%
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing contourpy (1.2.1): Installing...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing executing (2.0.1): Installing...
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Pending...
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing fonttools (4.51.0): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Installing...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 0%
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Installing...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 0%
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Pending...
#   - Installing joblib (1.4.0): Pending...
#   - Installing joblib (1.4.0): Pending...
#   - Installing huggingface-hub (0.21.4): Downloading... 0%
#   - Installing joblib (1.4.0): Pending...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Installing...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 0%
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Downloading... 0%
#   - Installing joblib (1.4.0): Pending...
#   - Installing blis (0.7.11): Downloading... 40%
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1): Installing...
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 0%
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Downloading... 0%
#   - Installing joblib (1.4.0): Pending...
#   - Installing joblib (1.4.0): Pending...
#   - Installing huggingface-hub (0.21.4): Downloading... 100%
#   - Installing joblib (1.4.0): Pending...
#   - Installing joblib (1.4.0): Downloading... 0%
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 0%
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Downloading... 100%
#   - Installing joblib (1.4.0): Downloading... 0%
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 0%
#   - Installing httpx (0.27.0): Installing...
#   - Installing huggingface-hub (0.21.4): Downloading... 100%
#   - Installing joblib (1.4.0): Downloading... 0%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing huggingface-hub (0.21.4): Downloading... 100%
#   - Installing joblib (1.4.0): Downloading... 0%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Downloading... 100%
#   - Installing joblib (1.4.0): Downloading... 0%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing joblib (1.4.0): Downloading... 100%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Downloading... 100%
#   - Installing joblib (1.4.0): Downloading... 100%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing fonttools (4.51.0): Downloading... 30%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Downloading... 100%
#   - Installing joblib (1.4.0): Downloading... 100%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing joblib (1.4.0): Downloading... 100%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Downloading... 100%
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing jsonschema (4.21.1): Downloading... 0%
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing jsonschema (4.21.1): Downloading... 100%
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing fonttools (4.51.0): Downloading... 50%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 50%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing blis (0.7.11): Downloading... 60%
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 50%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1): Installing...
#   - Installing kiwisolver (1.4.5): Pending...
#   - Installing kiwisolver (1.4.5): Downloading... 0%
#   - Installing kiwisolver (1.4.5): Downloading... 0%
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Downloading... 0%
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 50%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Downloading... 0%
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing blis (0.7.11): Downloading... 70%
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 50%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Downloading... 0%
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Downloading... 0%
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing fonttools (4.51.0): Downloading... 80%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4): Installing...
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Downloading... 0%
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing kiwisolver (1.4.5): Downloading... 90%
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing kiwisolver (1.4.5): Downloading... 100%
#   - Installing llvmlite (0.42.0): Pending...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Downloading... 100%
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Downloading... 100%
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Pending...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Pending...
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Pending...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Pending...
#   - Installing fonttools (4.51.0): Downloading... 100%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Pending...
#   - Installing omegaconf (2.3.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Downloading... 100%
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 100%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing blis (0.7.11): Downloading... 90%
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Downloading... 100%
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing joblib (1.4.0)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0): Installing...
#   - Installing pandas (2.2.2): Pending...
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing parso (0.8.4): Pending...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing parso (0.8.4): Pending...
#   - Installing fonttools (4.51.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing parso (0.8.4): Pending...
#   - Installing parso (0.8.4): Downloading... 0%
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing parso (0.8.4): Downloading... 0%
#   - Installing blis (0.7.11): Downloading... 100%
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 0%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 0%
#   - Installing parso (0.8.4): Downloading... 0%
#   - Installing parso (0.8.4): Downloading... 0%
#   - Installing pandas (2.2.2): Downloading... 10%
#   - Installing parso (0.8.4): Downloading... 0%
#   - Installing parso (0.8.4): Downloading... 100%
#   - Installing parso (0.8.4): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 10%
#   - Installing parso (0.8.4): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 10%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 10%
#   - Installing parso (0.8.4): Installing...
#   - Installing parso (0.8.4): Installing...
#   - Installing pandas (2.2.2): Downloading... 20%
#   - Installing parso (0.8.4): Installing...
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Pending...
#   - Installing llvmlite (0.42.0): Downloading... 10%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 20%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Pending...
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Downloading... 10%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 20%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Pending...
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Pending...
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Pending...
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing pillow (10.3.0): Downloading... 0%
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 0%
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing llvmlite (0.42.0): Downloading... 20%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 0%
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Downloading... 20%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 0%
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing blis (0.7.11): Installing...
#   - Installing cffi (1.16.0)
#   - Installing cloudpathlib (0.16.0)
#   - Installing colorama (0.4.6)
#   - Installing confection (0.1.4)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.51.0): Installing...
#   - Installing httpx (0.27.0)
#   - Installing huggingface-hub (0.21.4)
#   - Installing joblib (1.4.0)
#   - Installing jsonschema (4.21.1)
#   - Installing kiwisolver (1.4.5)
#   - Installing llvmlite (0.42.0): Downloading... 20%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 40%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 0%
#   - Installing platformdirs (4.2.0): Pending...
#   - Installing platformdirs (4.2.0): Downloading... 0%
#   - Installing platformdirs (4.2.0): Downloading... 100%
#   - Installing platformdirs (4.2.0): Installing...
#   - Installing platformdirs (4.2.0): Installing...
#   - Installing pillow (10.3.0): Downloading... 20%
#   - Installing platformdirs (4.2.0): Installing...
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 20%
#   - Installing platformdirs (4.2.0): Installing...
#   - Installing pandas (2.2.2): Downloading... 70%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 20%
#   - Installing platformdirs (4.2.0): Installing...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Pending...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Pending...
#   - Installing pillow (10.3.0): Downloading... 40%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Pending...
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 40%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Pending...
#   - Installing pandas (2.2.2): Downloading... 80%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 40%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Pending...
#   - Installing preshed (3.0.9): Downloading... 0%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Downloading... 0%
#   - Installing pillow (10.3.0): Downloading... 70%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Downloading... 0%
#   - Installing preshed (3.0.9): Downloading... 100%
#   - Installing preshed (3.0.9): Installing...
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 70%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Installing...
#   - Installing pandas (2.2.2): Downloading... 90%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 70%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 90%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 70%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 30%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 90%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 70%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9): Installing...
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0): Pending...
#   - Installing ptyprocess (0.7.0): Downloading... 0%
#   - Installing ptyprocess (0.7.0): Downloading... 100%
#   - Installing ptyprocess (0.7.0): Installing...
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2): Pending...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2): Pending...
#   - Installing pillow (10.3.0): Downloading... 100%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2): Pending...
#   - Installing pure-eval (0.2.2): Downloading... 0%
#   - Installing pure-eval (0.2.2): Downloading... 100%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 100%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2): Downloading... 100%
#   - Installing pandas (2.2.2): Downloading... 100%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Downloading... 100%
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2): Downloading... 100%
#   - Installing pure-eval (0.2.2): Installing...
#   - Installing pure-eval (0.2.2)
#   - Installing pyparsing (3.1.2): Pending...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2)
#   - Installing pyparsing (3.1.2): Pending...
#   - Installing pillow (10.3.0): Installing...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2)
#   - Installing pyparsing (3.1.2): Pending...
#   - Installing pyparsing (3.1.2): Downloading... 0%
#   - Installing pyparsing (3.1.2): Downloading... 100%
#   - Installing pyparsing (3.1.2): Installing...
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 100%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Installing...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2)
#   - Installing pyparsing (3.1.2): Installing...
#   - Installing llvmlite (0.42.0): Downloading... 40%
#   - Installing omegaconf (2.3.0)
#   - Installing pandas (2.2.2): Downloading... 100%
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0): Installing...
#   - Installing platformdirs (4.2.0)
#   - Installing preshed (3.0.9)
#   - Installing ptyprocess (0.7.0)
# ...
#   - Installing pytest (8.1.1): Pending...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Downloading... 100%
#   - Installing pytest (8.1.1): Pending...
#   - Installing ninja (1.11.1.1): Downloading... 100%
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Downloading... 100%
#   - Installing pytest (8.1.1): Pending...
#   - Installing pytest (8.1.1): Pending...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Downloading... 100%
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing deepfilternet (0.5.6): Downloading... 0%
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Downloading... 100%
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing deepfilternet (0.5.6): Downloading... 0%
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing audiocraft (1.2.0): Downloading... 100%
#   - Installing deepfilternet (0.5.6): Downloading... 0%
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing deepfilternet (0.5.6): Downloading... 0%
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing audiocraft (1.2.0): Preparing...
#   - Installing deepfilternet (0.5.6): Downloading... 0%
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing deepfilternet (0.5.6): Downloading... 100%
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0): Installing...
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Pending...
#   - Installing pytest (8.1.1): Downloading... 0%
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Downloading... 0%
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing deepfilternet (0.5.6): Installing...
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1): Installing...
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing pytest (8.1.1): Downloading... 100%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Downloading... 100%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing ninja (1.11.1.1)
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Downloading... 100%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 100%
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing pytest (8.1.1): Installing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.5.1): Pending...
#   - Installing tiktoken (0.5.1): Downloading... 0%
#   - Installing tiktoken (0.5.1): Downloading... 0%
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1): Downloading... 0%
#   - Installing tyro (0.7.3): Pending...
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1)
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Installing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1): Downloading... 0%
#   - Installing tyro (0.7.3): Pending...
#   - Installing deepfilternet (0.5.6)
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1)
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0): Installing...
#   - Installing pytest (8.1.1): Installing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1): Downloading... 0%
#   - Installing tyro (0.7.3): Pending...
#   - Installing pytest (8.1.1): Installing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1): Downloading... 0%
#   - Installing tyro (0.7.3): Pending...
#   - Installing pre-commit (3.7.0)
#   - Installing pytest (8.1.1): Installing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1): Downloading... 0%
#   - Installing tyro (0.7.3): Pending...
#   - Installing tyro (0.7.3): Pending...
#   - Installing tiktoken (0.5.1): Downloading... 90%
#   - Installing tyro (0.7.3): Pending...
#   - Installing tyro (0.7.3): Downloading... 0%
#   - Installing tyro (0.7.3): Downloading... 100%
#   - Installing tyro (0.7.3): Downloading... 100%
#   - Installing tiktoken (0.5.1): Downloading... 100%
#   - Installing tyro (0.7.3): Downloading... 100%
#   - Installing tyro (0.7.3): Installing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1): Downloading... 100%
#   - Installing tyro (0.7.3): Installing...
#   - Installing pytest (8.1.1)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1): Downloading... 100%
#   - Installing tyro (0.7.3): Installing...
#   - Installing tyro (0.7.3): Installing...
#   - Installing tiktoken (0.5.1): Installing...
#   - Installing tyro (0.7.3): Installing...
#   - Installing tyro (0.7.3)
#   - Installing tyro (0.7.3)
#   - Installing tiktoken (0.5.1)
#   - Installing tyro (0.7.3)
#   - Installing deepfilternet (0.5.6)
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1)
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0)
#   - Installing pytest (8.1.1)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1)
#   - Installing tyro (0.7.3)
#   - Installing audiocraft (1.2.0): Installing...
#   - Installing deepfilternet (0.5.6)
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1)
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0)
#   - Installing pytest (8.1.1)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1)
#   - Installing tyro (0.7.3)
# Installing /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages/tests/__init__.py over existing file
#   - Installing deepfilternet (0.5.6)
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1)
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0)
#   - Installing pytest (8.1.1)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1)
#   - Installing tyro (0.7.3)
#   - Installing audiocraft (1.2.0)
#   - Installing deepfilternet (0.5.6)
#   - Installing ipdb (0.13.13)
#   - Installing ninja (1.11.1.1)
#   - Installing posthog (3.5.0)
#   - Installing pre-commit (3.7.0)
#   - Installing pytest (8.1.1)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.5.1)
#   - Installing tyro (0.7.3)
#
# Installing the current project: fam (0.1.0)Installing the current project: fam (0.1.0)
# Collecting torch==2.2.1
#   Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchaudio==2.2.1
#   Downloading torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (4.11.0)
# Requirement already satisfied: sympy in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (1.12)
# Requirement already satisfied: networkx in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (3.3)
# Requirement already satisfied: jinja2 in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (3.1.3)
# Requirement already satisfied: fsspec in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from torch==2.2.1) (2024.3.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.1)
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from jinja2->torch==2.2.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /root/.cache/pypoetry/virtualenvs/fam-PCy6KQGI-py3.10/lib/python3.10/site-packages (from sympy->torch==2.2.1) (1.3.0)
# Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 41.8 MB/s eta 0:00:00
# Downloading torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 53.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 164.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 173.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 40.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 16.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 64.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 63.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 66.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 72.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 64.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 24.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 75.4 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0
#     Uninstalling torch-2.1.0:
#       Successfully uninstalled torch-2.1.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.1.0
#     Uninstalling torchaudio-2.1.0:
#       Successfully uninstalled torchaudio-2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# audiocraft 1.2.0 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
# xformers 0.0.22.post7 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.6.77 nvidia-nvtx-cu12-12.1.105 torch-2.2.1 torchaudio-2.2.1 triton-2.2.0

# %%
import sys, pathlib
venv = pathlib.Path("poetry_env.txt").read_text().strip("\n")
sys.path.append(f"/root/.cache/pypoetry/virtualenvs/{venv}/lib/python3.10/site-packages")

# %% [markdown]
# ## Inference

# %%
from IPython.display import Audio, display
from fam.llm.fast_inference import TTS

tts = TTS()

wav_file = tts.synthesise(
  text="This is a demo of text to speech by MetaVoice-1B, an open-source foundational audio model.",
  spk_ref_path="girl_aria.mp3" # you can use any speaker reference file (WAV, OGG, MP3, FLAC, etc.)
)
display(Audio(wav_file, autoplay=True))
# Out:
# using dtype=float16
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-10-1ac00c833092> in <cell line: 4>()
#       2 from fam.llm.fast_inference import TTS
#       3
# ----> 4 tts = TTS()
#
# /content/metavoice-src/fam/llm/fast_inference.py in __init__(self, model_name, seed, output_dir, quantisation_mode, first_stage_path, telemetry_origin)
#      89         )
#      90         data_adapter_second_stage = TiltedEncodec(end_of_audio_token=self.END_OF_AUDIO_TOKEN)
# ---> 91         self.llm_second_stage = Model(
#      92             config_second_stage, TrainedBPETokeniser, EncodecDecoder, data_adapter_fn=data_adapter_second_stage.decode
#      93         )
#
# /content/metavoice-src/fam/llm/inference.py in __init__(self, config, tokenizer_cls, decoder_cls, data_adapter_fn, use_kv_cache)
#      91         self.smodel = None
#      92
# ---> 93         self._init_model()
#      94
#      95         self.tokenizer = tokenizer_cls(**self.meta["tokenizer"])
#
# /content/metavoice-src/fam/llm/inference.py in _init_model(self)
#     103         if self.config.init_from == "resume":
#     104             # init from a model saved in a specific directory
# --> 105             checkpoint = torch.load(self.config.ckpt_path, map_location=self.config.device)
#     106             self.vocab_sizes = checkpoint["model_args"]["vocab_sizes"]
#     107
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1358                     except pickle.UnpicklingError as e:
#    1359                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1360                 return _load(
#    1361                     opened_zipfile,
#    1362                     map_location,
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1846     global _serialization_tls
#    1847     _serialization_tls.map_location = map_location
# -> 1848     result = unpickler.load()
#    1849     _serialization_tls.map_location = None
#    1850
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in persistent_load(saved_id)
#    1810         else:
#    1811             nbytes = numel * torch._utils._element_size(dtype)
# -> 1812             typed_storage = load_tensor(
#    1813                 dtype, nbytes, key, _maybe_decode_ascii(location)
#    1814             )
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load_tensor(dtype, numel, key, location)
#    1782         # stop wrapping with TypedStorage
#    1783         typed_storage = torch.storage.TypedStorage(
# -> 1784             wrap_storage=restore_location(storage, location),
#    1785             dtype=dtype,
#    1786             _internal=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in restore_location(storage, location)
#    1683
#    1684         def restore_location(storage, location):
# -> 1685             return default_restore_location(storage, map_location)
#    1686
#    1687     elif isinstance(map_location, torch.device):
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in default_restore_location(storage, location)
#     599     """
#     600     for _, _, fn in _package_registry:
# --> 601         result = fn(storage, location)
#     602         if result is not None:
#     603             return result
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _deserialize(backend_name, obj, location)
#     538     if location.startswith(backend_name):
#     539         device = _validate_device(location, backend_name)
# --> 540         return obj.to(device=device)
#     541
#     542
#
# /usr/local/lib/python3.10/dist-packages/torch/storage.py in to(self, device, non_blocking)
#     277         self, *, device: torch.device, non_blocking: _bool = False
#     278     ) -> Union[_StorageBase, TypedStorage]:
# --> 279         return _to(self, device, non_blocking)
#     280
#     281     def double(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py in _to(self, device, non_blocking)
#      86                 not self.is_sparse
#      87             ), f"sparse storage is not supported for {device.type.upper()} tensors"
# ---> 88             untyped_storage = torch.UntypedStorage(self.size(), device=device)
#      89             untyped_storage.copy_(self, non_blocking)
#      90             return untyped_storage
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.75 GiB of which 9.06 MiB is free. Process 5045 has 14.74 GiB memory in use. Of the allocated memory 14.61 GiB is allocated by PyTorch, and 7.93 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
wav_file = tts.synthesise(
  text="This is a demo of text to speech by MetaVoice-1B, an open-source foundational audio model.",
  spk_ref_path="girl_aria.mp3" # you can use any speaker reference file (WAV, OGG, MP3, FLAC, etc.)
)
display(Audio(wav_file, autoplay=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a5663a706c92> in <cell line: 1>()
# ----> 1 wav_file = tts.synthesise(
#       2   text="This is a demo of text to speech by MetaVoice-1B, an open-source foundational audio model.",
#       3   spk_ref_path="girl_aria.mp3" # you can use any speaker reference file (WAV, OGG, MP3, FLAC, etc.)
#       4 )
#       5 display(Audio(wav_file, autoplay=True))
#
# NameError: name 'tts' is not defined
